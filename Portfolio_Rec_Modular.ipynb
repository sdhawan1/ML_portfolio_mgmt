# %%
#first, ready the data for analysis. store it in folders.

import csv
import numpy as np
import pandas as pd

#find a way to filter the input data...
# to modify: can add input / output files as fn input/output.
def input_df_from_csv():
    stocks_df = pd.read_csv('data/stocks_daily_raw_10yr.csv')
    print("input data head:")
    print(stocks_df.head())
    
    #filter inputs & recreate index
    stocks_df_5yr = stocks_df[1511:]
    stocks_df_5yr = stocks_df_5yr.reset_index(drop=True)
    print("\n=================\nfiltered (x yr) data head:")
    print(stocks_df_5yr.head())
    
    
    #filter out the nulls
    stocks_ser = stocks_df_5yr.isnull().sum()
    stocks_ser_nonnulls = stocks_ser[stocks_ser <= 20]
    nnullkeys = stocks_ser_nonnulls.keys()
    print("\nNon-null keys: ", nnullkeys)
    nnull_stocks_df = stocks_df_5yr[nnullkeys]
    #print(nnull_stocks_df.head())

    #convert NaN's to 0.
    #"X" should be ready for pca
    X = nnull_stocks_df.iloc[:,1:-1]
    X = X.fillna(0)
    
    print(X.head())
    
    #perform cumulative product:
    X_cp = (1+X).cumprod()
    print("\n=================\ncomputing cumulative returns:")
    print(X_cp.tail())
    X = X_cp
    
    #do a null check: if nulls, throw error?
    print("\n=================\ncheckign for nulls:")
    nullsums = X.isnull().sum()
    print(nullsums[nullsums >0])
    
    #store X in a csv
    X.to_csv('data/input_stocks_data_X.csv')

    
#run (test) the above
input_df_from_csv()
# Out:
# input data head:
#          Date         A        AA      AAME       AAN      AAON       AAP  \
# 0  2010-01-05 -0.010863 -0.031231  0.060606  0.009062 -0.029015 -0.005943
# 1  2010-01-06 -0.003553  0.052077  0.000000  0.000000 -0.039670  0.008719
# 2  2010-01-07 -0.001297 -0.021214 -0.057143  0.008083  0.037017 -0.000247
# 3  2010-01-08 -0.000324  0.024684  0.053030 -0.006681  0.011898  0.003953
# 4  2010-01-11  0.000649  0.025264  0.043166  0.015695  0.027096 -0.009843
#
#    AAT      AAPL      AAWW  ...      ZBRA      ZEUS      ZION      ZIOP  \
# 0  NaN  0.001729  0.055236  ... -0.001744 -0.006500  0.035259  0.033898
# 1  NaN -0.015906 -0.041677  ... -0.007687  0.039251  0.086957  0.009836
# 2  NaN -0.001849  0.008284  ... -0.025000 -0.012876  0.112000 -0.012987
# 3  NaN  0.006648  0.008216  ... -0.003250  0.031305 -0.016187  0.019737
# 4  NaN -0.008821  0.003056  ...  0.003261 -0.027544  0.006094  0.029032
#
#        ZIXI        ZN  ZNGA      ZOLT      ZUMZ        SP
# 0 -0.044944 -0.015278   NaN -0.009137 -0.005663  0.003116
# 1  0.000000 -0.016925   NaN -0.009221  0.031733  0.000546
# 2  0.305882  0.004304   NaN -0.008273  0.156151  0.004001
# 3 -0.045045  0.007143   NaN  0.015641  0.004775  0.002882
# 4 -0.018868 -0.028369   NaN  0.016427 -0.023761  0.001747
#
# [5 rows x 2426 columns]
#
# =================
# filtered (x yr) data head:
#          Date         A        AA      AAME       AAN      AAON       AAP  \
# 0  2016-01-06  0.004439 -0.071197  0.028446 -0.075692 -0.018552 -0.026455
# 1  2016-01-07 -0.042475 -0.039489 -0.025532 -0.032756 -0.022130  0.011073
# 2  2016-01-08 -0.010513 -0.024184 -0.026201 -0.016449 -0.032532 -0.021971
# 3  2016-01-11 -0.016844 -0.008674 -0.044843  0.010821  0.006823  0.010236
# 4  2016-01-12  0.006589 -0.090000  0.004695  0.104623 -0.005808  0.006936
#
#         AAT      AAPL      AAWW  ...      ZBRA      ZEUS      ZION      ZIOP  \
# 0 -0.001032 -0.019570 -0.018337  ... -0.039957  0.000000 -0.029145 -0.087719
# 1 -0.021431 -0.042205 -0.080860  ... -0.045316 -0.057461 -0.030020 -0.023352
# 2 -0.008971  0.005288 -0.019766  ... -0.002693 -0.032757 -0.011254 -0.015471
# 3  0.006656  0.016192 -0.041749  ... -0.006582 -0.089370 -0.019919 -0.098571
# 4 -0.007405  0.014514  0.018376  ...  0.016820 -0.007232 -0.004148 -0.006339
#
#        ZIXI        ZN      ZNGA  ZOLT      ZUMZ        SP
# 0 -0.018480 -0.026738  0.003906   NaN -0.015023 -0.013115
# 1  0.000000 -0.010989 -0.035019   NaN  0.114721 -0.023700
# 2 -0.039749  0.005556 -0.028226   NaN -0.011303 -0.010838
# 3  0.026144 -0.022099 -0.008299   NaN  0.028279  0.000853
# 4  0.002123 -0.056497  0.000000   NaN -0.005851  0.007803
#
# [5 rows x 2426 columns]
#
# Non-null keys:  Index(['Date', 'A', 'AA', 'AAME', 'AAN', 'AAON', 'AAP', 'AAT', 'AAPL', 'AAWW',
#        ...
#        'ZAZA', 'ZBRA', 'ZEUS', 'ZION', 'ZIOP', 'ZIXI', 'ZN', 'ZNGA', 'ZUMZ',
#        'SP'],
#       dtype='object', length=2147)
#           A        AA      AAME       AAN      AAON       AAP       AAT  \
# 0  0.004439 -0.071197  0.028446 -0.075692 -0.018552 -0.026455 -0.001032
# 1 -0.042475 -0.039489 -0.025532 -0.032756 -0.022130  0.011073 -0.021431
# 2 -0.010513 -0.024184 -0.026201 -0.016449 -0.032532 -0.021971 -0.008971
# 3 -0.016844 -0.008674 -0.044843  0.010821  0.006823  0.010236  0.006656
# 4  0.006589 -0.090000  0.004695  0.104623 -0.005808  0.006936 -0.007405
#
#        AAPL      AAWW       ABC  ...      ZAGG      ZAZA      ZBRA      ZEUS  \
# 0 -0.019570 -0.018337 -0.015286  ... -0.016949 -0.297030 -0.039957  0.000000
# 1 -0.042205 -0.080860 -0.031932  ... -0.007663  0.547887 -0.045316 -0.057461
# 2  0.005288 -0.019766 -0.005785  ... -0.066602 -0.362147 -0.002693 -0.032757
# 3  0.016192 -0.041749 -0.039812  ... -0.031024  0.034237 -0.006582 -0.089370
# 4  0.014514  0.018376  0.001276  ...  0.038420 -0.020690  0.016820 -0.007232
#
#        ZION      ZIOP      ZIXI        ZN      ZNGA      ZUMZ
# 0 -0.029145 -0.087719 -0.018480 -0.026738  0.003906 -0.015023
# 1 -0.030020 -0.023352  0.000000 -0.010989 -0.035019  0.114721
# 2 -0.011254 -0.015471 -0.039749  0.005556 -0.028226 -0.011303
# 3 -0.019919 -0.098571  0.026144 -0.022099 -0.008299  0.028279
# 4 -0.004148 -0.006339  0.002123 -0.056497  0.000000 -0.005851
#
# [5 rows x 2145 columns]
#
# =================
# computing cumulative returns:
#              A        AA      AAME       AAN      AAON       AAP       AAT  \
# 999   2.179559  0.982469  0.423287  2.546768  2.324320  1.069287  1.281088
# 1000  2.183391  0.976551  0.425526  2.493783  2.328987  1.060630  1.287103
# 1001  2.182625  0.982469  0.414328  2.466634  2.324787  1.054503  1.295982
# 1002  2.173919  0.971543  0.430006  2.490280  2.304717  1.059631  1.303142
# 1003  2.184417  0.979282  0.441204  2.500789  2.306117  1.066557  1.314598
#
#           AAPL      AAWW       ABC  ...      ZAGG     ZAZA      ZBRA  \
# 999   2.961773  0.688772  0.887016  ...  0.742938  0.00099  3.923635
# 1000  3.020536  0.695303  0.883174  ...  0.743879  0.00099  3.925023
# 1001  3.019389  0.674956  0.881720  ...  0.723164  0.00099  3.949398
# 1002  3.037310  0.667671  0.868532  ...  0.744821  0.00099  3.920241
# 1003  3.059502  0.692540  0.882862  ...  0.763653  0.00099  3.940759
#
#           ZEUS      ZION      ZIOP      ZIXI        ZN      ZNGA      ZUMZ
# 999   1.567672  2.086283  0.649123  1.439425  0.101604  2.472656  2.107773
# 1000  1.576406  2.091547  0.620301  1.398357  0.096257  2.460938  2.164598
# 1001  1.542345  2.085069  0.645363  1.396304  0.090909  2.441406  2.133899
# 1002  1.541472  2.096000  0.600251  1.390144  0.085561  2.398438  2.218158
# 1003  1.565052  2.102073  0.591479  1.392197  0.090909  2.390625  2.256042
#
# [5 rows x 2145 columns]
#
# =================
# checkign for nulls:
# Series([], dtype: int64)

# %%
#next, compute the pca and come up with the eigen-portfolios
# eigen-portfolios should be stored in a pickled list object.
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pickle as pkl

def find_eigen_portfolios(colnames, pcs):
    epfs = []
    epfs_inv = []

    for i in range(len(pcs)):
        #want to inspect & create cutoffs.
        ci = pcs[i]

        #debug
        #print(len(ci))

        maxi = max(ci)
        mini = min(ci)
        print("***** starting with pc #{}".format(i))
        print("max: ", max(ci), "min: ", min(ci))

        #find # correlations greater than half of max, or less than half of min.
        csig_pos = np.arange(len(ci))[ci > maxi/2]
        csig_neg = np.arange(len(ci))[ci < mini/2]
        print("significance lengths")
        print(len(csig_pos))
        print(len(csig_neg))

        #create lists of tickers.
        csig = csig_pos if len(csig_pos) >= len(csig_neg) else csig_neg
        csig_inv = csig_neg if len(csig_pos) >= len(csig_neg) else csig_pos
        ptiks = [colnames[i] for i in csig]
        ptiks_inv = [colnames[i] for i in csig_inv]

        epfs.append(ptiks)
        epfs_inv.append(ptiks_inv)
        print(ptiks[:20])
        
    with open('data/pcs/eigenportfolios.pkl', 'wb') as fout:
        pkl.dump(epfs, fout)
    with open('data/pcs/eigenportfolios_inv.pkl', 'wb') as fout:
        pkl.dump(epfs_inv, fout)
    
    

def compute_pca_eigen_portfolios():
    X = pd.read_csv('data/input_stocks_data_X.csv')
    colnames = list(X.columns)
    print(colnames)
    #scale X
    scaler = StandardScaler()
    scaled_x = scaler.fit_transform(X)
    #perform PCA
    print("\n=================\nPerforming PCA...")
    pca = PCA(n_components=5)
    Xpca = pca.fit_transform(scaled_x)
    print("transformed data (Xpca) shape & values:")
    print(Xpca.shape)
    print(Xpca)
    
    #results analysis:
    #print the variance ratio
    print("\n\nexplained variance: ", pca.explained_variance_ratio_)
    #print the singular values
    print("\nsingular values: ", pca.singular_values_)
    #print pca components and their shape:
    print("\ncomponents shape & values: ", pca.components_.shape)
    print(pca.components_)
    
    #save pc's in a file.
    pc_df = pd.DataFrame(data=pca.components_)
    with open('data/pcs/principal_components.csv', 'w') as fout:
        pc_df.to_csv(fout)
    
    #next, come up with the eigen portfolios as identified by the PC's
    find_eigen_portfolios(colnames, pca.components_)

compute_pca_eigen_portfolios()
# Out:
# ['Unnamed: 0', 'A', 'AA', 'AAME', 'AAN', 'AAON', 'AAP', 'AAT', 'AAPL', 'AAWW', 'ABC', 'ABCB', 'AB', 'ABG', 'ABIO', 'ABM', 'ABMC', 'ABMD', 'ABT', 'ACAD', 'ABR', 'ACC', 'ACFN', 'ACCO', 'ACGL', 'ACHC', 'ACIW', 'ACM', 'ACLS', 'ACN', 'ACNB', 'ACOR', 'ACRE', 'ACRX', 'ACTG', 'ACU', 'ACUR', 'ACY', 'ADBE', 'ADC', 'ADES', 'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'ADUS', 'ADTN', 'AE', 'AEE', 'AEGN', 'AEHR', 'AEIS', 'AEL', 'AEO', 'AEP', 'AERG', 'AES', 'AEY', 'AFFY', 'AFH', 'AFG', 'AFL', 'AGCO', 'AGEN', 'AGM', 'AGN', 'AGNC', 'AGO', 'AGX', 'AGYS', 'AHC', 'AHL', 'AHPI', 'AHT', 'AI', 'AIG', 'AIMC', 'AIR', 'AIRT', 'AIT', 'AIV', 'AIZ', 'AJG', 'AKR', 'AKAM', 'AKRX', 'AKS', 'ALB', 'ALCO', 'ALE', 'ALGT', 'ALGN', 'ALK', 'ALKS', 'ALL', 'ALG', 'ALEX', 'ALNY', 'ALOT', 'ALSE', 'ALSK', 'ALSN', 'ALV', 'ALXN', 'AMAG', 'AMAT', 'ALX', 'AMBA', 'AMCF', 'AMCX', 'AMD', 'AME', 'AMED', 'AMG', 'AMGN', 'AMIN', 'AMKR', 'AMNB', 'AMOT', 'AMP', 'AMPE', 'AMRB', 'AMRC', 'AMRS', 'AMSC', 'AMSF', 'AMS', 'AMSWA', 'AMT', 'AMTD', 'AMTY', 'AMWD', 'AN', 'AMZN', 'ANAT', 'ANGI', 'ANF', 'ANGO', 'ANIK', 'ANDE', 'ANH', 'ANSS', 'ANTH', 'ANV', 'AOS', 'AOSL', 'AP', 'APA', 'APAM', 'APD', 'APEI', 'APH', 'APO', 'APOG', 'APP', 'APT', 'ARAY', 'ARCW', 'ARI', 'ARKR', 'ARL', 'ARLP', 'ARNA', 'AROW', 'ARQL', 'ARR', 'ARTNA', 'ARTW', 'ARE', 'ARTX', 'ARW', 'ARWR', 'ASH', 'ASNA', 'ASPS', 'ASTC', 'ASTE', 'ASTI', 'ASRV', 'ASUR', 'ASYS', 'ATEC', 'ATHX', 'ATI', 'ATLC', 'ATNI', 'ATO', 'ATOS', 'ATR', 'ATLO', 'ATRO', 'ATRS', 'ATRC', 'ATRI', 'ASFI', 'ATVI', 'ATW', 'AUBN', 'AVA', 'AVAV', 'AVB', 'AVEO', 'AVID', 'AVGO', 'AVNW', 'AVP', 'AVSR', 'AVT', 'AVX', 'AVY', 'AWI', 'AWK', 'AWRE', 'AWX', 'AXAS', 'AXDX', 'AXE', 'AXL', 'AXP', 'AXR', 'AXS', 'AXTI', 'AYI', 'AZO', 'AZPN', 'B', 'AZZ', 'BA', 'BAC', 'BAH', 'BANF', 'BANC', 'BANR', 'BASI', 'BAX', 'BBBY', 'BBGI', 'BBSI', 'BBX', 'BC', 'BCC', 'BCEI', 'BCO', 'BCOR', 'BCOV', 'BCPC', 'BCRX', 'BDCO', 'BDGE', 'BDL', 'BDN', 'BDR', 'BDSI', 'BEBE', 'BDX', 'BECN', 'BELFA', 'BELFB', 'BEN', 'BERK', 'BERY', 'BFAM', 'BFIN', 'BG', 'BGCP', 'BGFV', 'BGG', 'BGMD', 'BGS', 'BH', 'BHB', 'BHE', 'BIG', 'BIIB', 'BIOC', 'BIOL', 'BJRI', 'BKD', 'BKE', 'BKH', 'BKOR', 'BKU', 'BLDR', 'BLIN', 'BLKB', 'BLL', 'BLK', 'BLMN', 'BMC', 'BMI', 'BMTC', 'BMY', 'BOCH', 'BOH', 'BOKF', 'BOOM', 'BPFH', 'BOX', 'BOTJ', 'BPOP', 'BR', 'BRC', 'BREW', 'BRID', 'BRKL', 'BRKR', 'BRKS', 'BRN', 'BRO', 'BRT', 'BSET', 'BSPM', 'BSQR', 'BSRR', 'BSX', 'BTN', 'BUSE', 'BVSN', 'BWA', 'BXC', 'BXP', 'BXS', 'BYD', 'BYFC', 'BZH', 'C', 'CAAS', 'CAC', 'CACC', 'CACI', 'CACH', 'CAG', 'CAH', 'CAFI', 'CAKE', 'CALI', 'CALM', 'CALX', 'CAMP', 'CAP', 'CAR', 'CARV', 'CASH', 'CASS', 'CASY', 'CAT', 'CATM', 'CATO', 'CATY', 'CB', 'CBAN', 'CBB', 'CBLI', 'CBL', 'CBOE', 'CBPO', 'CBRL', 'CBS', 'CBSH', 'CBT', 'CBU', 'CBZ', 'CCBG', 'CCF', 'CCI', 'CCK', 'CCL', 'CCMP', 'CCNE', 'CCO', 'CCOI', 'CCRN', 'CCUR', 'CDE', 'CDR', 'CDXS', 'CDNS', 'CDZI', 'CECE', 'CDTI', 'CENT', 'CENTA', 'CEMI', 'CENX', 'CERN', 'CERS', 'CETV', 'CEVA', 'CF', 'CFBK', 'CFFN', 'CFFI', 'CFI', 'CFNB', 'CFR', 'CFX', 'CG', 'CGA', 'CGNX', 'CHD', 'CHE', 'CHEF', 'CHCI', 'CHCO', 'CHGS', 'CHH', 'CHK', 'CHMG', 'CHMP', 'CHRW', 'CHS', 'CHSCP', 'CHUY', 'CI', 'CIDM', 'CIEN', 'CIM', 'CINF', 'CIR', 'CIT', 'CIX', 'CIZN', 'CJJD', 'CL', 'CLB', 'CLC', 'CLCT', 'CLDT', 'CKX', 'CLDX', 'CLF', 'CLFD', 'CLIR', 'CLNE', 'CLNY', 'CLR', 'CLRO', 'CLSN', 'CLW', 'CLVS', 'CLX', 'CLUB', 'CMC', 'CMA', 'CMCO', 'CME', 'CMCSA', 'CMFO', 'CMG', 'CMI', 'CMP', 'CMRX', 'CMTL', 'CNBKA', 'CNC', 'CNK', 'CNA', 'CNO', 'CNMD', 'CNOB', 'CNS', 'CNSL', 'CNX', 'CODI', 'COF', 'COG', 'COHR', 'COKE', 'COL', 'COHU', 'COLB', 'COLM', 'CONN', 'COO', 'COP', 'COR', 'CORT', 'CORX', 'COST', 'COT', 'COV', 'COWN', 'CPAH', 'CPB', 'CPE', 'CPF', 'CPIX', 'CPHC', 'CPRT', 'CPRX', 'CPSI', 'CPST', 'CPT', 'CRAI', 'CREE', 'CRIS', 'CRK', 'CRL', 'CRMD', 'CRMT', 'CROX', 'CRS', 'CRUS', 'CRVL', 'CRWS', 'CRY', 'CSC', 'CSCO', 'CSFL', 'CSGP', 'CSGS', 'CSHB', 'CSII', 'CSL', 'CSOD', 'CSPI', 'CSS', 'CSV', 'CSWC', 'CSX', 'CTAS', 'CTB', 'CTBI', 'CTG', 'CTHR', 'CTIB', 'CTL', 'CTO', ' ...
#
# =================
# Performing PCA...
# transformed data (Xpca) shape & values:
# (1004, 5)
# [[ 57.74198204  19.98714564  14.36192267 -14.78162706  -2.44382173]
#  [ 59.20564317  22.22765702  15.26339641 -15.92202864  -0.67926055]
#  [ 59.91548208  23.32471634  15.71087709 -16.2995902    0.54789564]
#  ...
#  [-52.77197141  22.67742428 -21.25239908  -1.13408716 -18.48299826]
#  [-52.60303568  22.76817194 -21.18228278  -0.99537954 -18.4845558 ]
#  [-52.83158143  22.5131644  -21.29456357  -0.9305564  -18.71460404]]
#
#
# explained variance:  [0.48774682 0.18719294 0.07924229 0.04875299 0.03627639]
#
# singular values:  [1024.41319551  634.63304224  412.9110089   323.87586937  279.3765808 ]
#
# components shape & values:  (5, 2146)
# [[-0.03008485 -0.02952156 -0.00750681 ...  0.00460699 -0.02723305
#   -0.02116391]
#  [ 0.01061695  0.00030889 -0.04503208 ... -0.03609502  0.01752772
#    0.0130399 ]
#  [-0.00102419 -0.00367748  0.0171073  ...  0.0153507  -0.01519279
#    0.00578096]
#  [ 0.00144975 -0.01114246 -0.0145675  ... -0.0385948  -0.00843811
#    0.01738564]
#  [ 0.00572387  0.01164551 -0.00318729 ... -0.01048295 -0.00028306
#   -0.05181501]]
# ***** starting with pc #0
# max:  0.03020939783146654 min:  -0.030374825721449245
# significance lengths
# 352
# 1200
# ***** starting with pc #1
# max:  0.042798810947246343 min:  -0.046254506580244575
# significance lengths
# 150
# 590
# ***** starting with pc #2
# max:  0.06189625127519567 min:  -0.06670668290243353
# significance lengths
# 146
# 162
# ***** starting with pc #3
# max:  0.08277834412960407 min:  -0.06950558451096471
# significance lengths
# 109
# 70
# ***** starting with pc #4
# max:  0.08446946654179238 min:  -0.08522547474437252
# significance lengths
# 35
# 87
# /Users/sidharth/Documents/ml/sideprojects/kaggle_env/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/sidharth/Documents/ml/sideprojects/kaggle_env/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#doublecheck the eigenportfolios found above.
with open('data/pcs/eigenportfolios.pkl', 'rb') as fin:
    epfs = pkl.load(fin)
    
    print(epfs)
print(epfs[0])
# Out:
# [['Unnamed: 0', 'A', 'AAN', 'AAON', 'AAPL', 'ABCB', 'AB', 'ABG', 'ABMD', 'ABT', 'ABR', 'ACFN', 'ACGL', 'ACIW', 'ACLS', 'ACN', 'ACNB', 'ACRE', 'ADBE', 'ADC', 'ADES', 'ADI', 'ADM', 'ADP', 'ADSK', 'ADUS', 'AEE', 'AEL', 'AEO', 'AEP', 'AERG', 'AES', 'AFG', 'AFL', 'AGCO', 'AGM', 'AGNC', 'AGO', 'AGYS', 'AHL', 'AIR', 'AIRT', 'AIT', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALCO', 'ALE', 'ALGN', 'ALL', 'ALG', 'ALNY', 'ALOT', 'ALSN', 'AMAT', 'AMD', 'AME', 'AMED', 'AMGN', 'AMNB', 'AMOT', 'AMP', 'AMRB', 'AMRC', 'AMSF', 'AMSWA', 'AMT', 'AMTD', 'AMZN', 'ANAT', 'ANGI', 'ANGO', 'ANSS', 'ANV', 'AOS', 'APAM', 'APD', 'APEI', 'APH', 'APO', 'APT', 'ARI', 'ARL', 'ARNA', 'AROW', 'ARQL', 'ARR', 'ARTNA', 'ARE', 'ARW', 'ARWR', 'ASH', 'ASRV', 'ATI', 'ATO', 'ATR', 'ATLO', 'ATRO', 'ATRS', 'ATRC', 'ATRI', 'ATVI', 'ATW', 'AUBN', 'AVA', 'AVAV', 'AVB', 'AVGO', 'AVNW', 'AVX', 'AVY', 'AWI', 'AWK', 'AXP', 'AZPN', 'B', 'BA', 'BAC', 'BAH', 'BANF', 'BANR', 'BASI', 'BAX', 'BBSI', 'BBX', 'BC', 'BCC', 'BCO', 'BCOR', 'BCPC', 'BDN', 'BDR', 'BDSI', 'BEBE', 'BDX', 'BERK', 'BFAM', 'BFIN', 'BHB', 'BKH', 'BKOR', 'BKU', 'BLDR', 'BLKB', 'BLL', 'BLK', 'BLMN', 'BMC', 'BMI', 'BMTC', 'BOCH', 'BOH', 'BOKF', 'BOOM', 'BOX', 'BOTJ', 'BPOP', 'BR', 'BRC', 'BRID', 'BRKL', 'BRKR', 'BRKS', 'BRO', 'BRT', 'BSRR', 'BSX', 'BUSE', 'BWA', 'BXC', 'BXP', 'BXS', 'BYD', 'C', 'CAC', 'CACC', 'CACI', 'CASH', 'CASS', 'CASY', 'CAT', 'CATY', 'CB', 'CBAN', 'CBOE', 'CBRL', 'CBSH', 'CBU', 'CBZ', 'CCBG', 'CCF', 'CCI', 'CCMP', 'CCNE', 'CCOI', 'CDXS', 'CDNS', 'CDZI', 'CENT', 'CENTA', 'CERN', 'CETV', 'CF', 'CFBK', 'CFFN', 'CFFI', 'CFNB', 'CFR', 'CG', 'CGNX', 'CHD', 'CHE', 'CHEF', 'CHCO', 'CHH', 'CHMG', 'CHRW', 'CHSCP', 'CI', 'CIEN', 'CIM', 'CINF', 'CIT', 'CIX', 'CLDT', 'CLF', 'CLX', 'CMC', 'CMA', 'CMCO', 'CME', 'CMCSA', 'CMG', 'CMI', 'CMTL', 'CNBKA', 'CNC', 'CNK', 'CNA', 'CNMD', 'CNOB', 'CNS', 'CODI', 'COF', 'COKE', 'COL', 'COHU', 'COLB', 'COLM', 'CONN', 'COO', 'COP', 'COR', 'CORT', 'COST', 'COWN', 'CPF', 'CPHC', 'CPRT', 'CPRX', 'CPT', 'CRAI', 'CREE', 'CRL', 'CRMT', 'CROX', 'CRS', 'CRVL', 'CRY', 'CSCO', 'CSFL', 'CSGP', 'CSGS', 'CSHB', 'CSII', 'CSL', 'CSOD', 'CSPI', 'CSWC', 'CSX', 'CTAS', 'CTBI', 'CTO', 'CTS', 'CTSH', 'CTXS', 'CUB', 'CUTR', 'CUZ', 'CVA', 'CVBF', 'CVCO', 'CVCY', 'CVGI', 'CVI', 'CVGW', 'CVLY', 'CVX', 'CW', 'CWBC', 'CWCO', 'CWST', 'CWT', 'CXP', 'CY', 'CYB', 'CZNC', 'CZWI', 'D', 'CZR', 'DAL', 'DAR', 'DCI', 'DCO', 'DCOM', 'DE', 'DECK', 'DEI', 'DENN', 'DFS', 'DG', 'DGII', 'DGX', 'DHI', 'DHR', 'DIOD', 'DISCB', 'DIS', 'DJCO', 'DK', 'DKL', 'DLB', 'DLA', 'DLR', 'DLTR', 'DMLP', 'DNKN', 'DORM', 'DOV', 'DRE', 'DPZ', 'DRH', 'DRI', 'DRL', 'DSPG', 'DTE', 'DUK', 'DX', 'DXCM', 'DXPE', 'EA', 'EBF', 'EBAY', 'EBMT', 'EBSB', 'EBTC', 'EBS', 'ECL', 'ECOL', 'ED', 'EDUC', 'EFC', 'EEFT', 'EFSC', 'EGAN', 'EGHT', 'EGY', 'EHTH', 'EIG', 'ELY', 'EME', 'ENPH', 'ENSG', 'ENTG', 'ENTA', 'ENV', 'ENZN', 'EPAM', 'EPAY', 'EQIX', 'ERIE', 'ESGR', 'ESE', 'ESSA', 'EVTC', 'EVR', 'EWBC', 'EV', 'EXAS', 'EXEL', 'EXLS', 'EXPO', 'EXTR', 'EXR', 'FABK', 'FAF', 'FANG', 'FARO', 'FAST', 'FB', 'FBC', 'FBMS', 'FBNC', 'FBP', 'FBSS', 'FC', 'FCAP', 'FCCY', 'FCBC', 'FCCO', 'FCF', 'FCFS', 'FCN', 'FCNCA', 'FDEF', 'FDS', 'FE', 'FELE', 'FFBC', 'FF', 'FFG', 'FFIN', 'FFIV', 'FIBK', 'FICO', 'FIS', 'FISI', 'FITB', 'FISV', 'FIVE', 'FIX', 'FLIR', 'FLL', 'FLO', 'FLOW', 'FLT', 'FLWS', 'FMBI', 'FMC', 'FMNB', 'FN', 'FNF', 'FNLC', 'FOLD', 'FOR', 'FORM', 'FORR', 'FR', 'FRD', 'FRME', 'FSBW', 'FSFG', 'FSI', 'FSTR', 'FTNT', 'FULT', 'FUNC', 'FUL', 'FWRD', 'G', 'GABC', 'GALT', 'GAS', 'GBCI', 'GCBC', 'GD', 'GDOT', 'GES', 'GFED', 'GFN', 'GGG', 'GHM', 'GLBZ', 'GLP', 'GLW', 'GLUU', 'GM', 'GMED', 'GNRC', 'GNTX', 'GOOD', 'GPC', 'GPI', 'GOOG', 'GPN', 'GRC', 'GRIF', 'GSBC', 'GSIT', 'GTLS', 'GTN', 'GWR', 'GWRE', 'H', 'HAE', 'HALO', 'HASI', 'HBCP', 'HBNC', 'HCA', 'HCCI', 'HCI', 'HCKT', 'HE', 'HEES', 'HEI', 'HFC', 'HES', 'HFWA', 'HI', 'HIG', 'HII', 'HLIT', 'HLF', 'HMG', 'HMN', 'HMNF', 'HMSY', 'HOLX', 'HMST', 'HON', 'HPP', 'HPQ', 'HRC', 'HRL', 'HSC', 'HSII', 'HSKA', 'HST', 'HSTM', 'HSY', 'HTBI', 'HTB ...

# %%
'''
method for encouraging diversity:
    - match each portfolio with the eigenportfolios and determine its similarity.

*> a better method might be to calculate squared sum of all the proper factor loadings.
    - then normalize the resulting vector. This might give you the ratio of the variance.

> or: perform a change of basis from portfolio market performance to principal components?
'''

#potentially todo: have a different input path for the principal components?
def diversity_recommendation():
    #first, identify the factor loadings of the portfolio stocks in each principal component.
    pcs = pd.read_csv('data/pcs/principal_components.csv')
    print(pcs.head())
    np_pcs = pcs.iloc[:,1:].to_numpy()

    #find all the right factor loadings in this result.
    portfolio = ['AAPL', 'AMZN', 'MSFT', 'INTC']

    X = pd.read_csv('data/input_stocks_data_X.csv')
    colnames = list(X.columns)
    #find index of all portfolio elements
    pf_inds = [colnames.index(p) for p in portfolio]
    print(pf_inds)

    #find the factor loadings of all pcs. Then do a squared sum.
    facloads = np_pcs[:, pf_inds]
    print("factor loadings: ", facloads)
    variances = (facloads**2).sum(1) #squares & sums across rows
    norm_vcs = variances / (sum(variances))
    print("\n")
    print("normalized var's in all pc's: ", norm_vcs)

    #print diff between correspondence in this pf, and overall market. Capture the max diff.
    mkt_vars = [0.48753289, 0.1872592,  0.07927921, 0.04877565, 0.03629214]
        ## TODO: NEED TO DO THIS^^ FOR THE COMPUTED PCA VARIANCES.
    missing_var = mkt_vars-norm_vcs
    print("where is pf variance behind market: ", missing_var)

    ### == return this result! == ###
    print("eigen pf to invest in: ", np.argmax(missing_var))
    print("eigen pf diversity weight: ", np.max(missing_var))

#run the above
diversity_recommendation()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.030085 -0.029522 -0.007507  0.027393 -0.028865 -0.027047
# 1           1  0.010617  0.000309 -0.045032 -0.011908  0.011115  0.011630
# 2           2 -0.001024 -0.003677  0.017107 -0.004644 -0.006589 -0.024006
# 3           3  0.001450 -0.011142 -0.014567 -0.008891 -0.006681  0.008691
# 4           4  0.005724  0.011646 -0.003187  0.005127  0.004913  0.003913
#
#           6         7         8  ...      2136      2137      2138      2139  \
# 0  0.000217 -0.014549 -0.029255  ... -0.009541  0.028054 -0.028925  0.007041
# 1  0.030397  0.030052  0.004319  ... -0.032078 -0.006984  0.014673 -0.030121
# 2  0.012653 -0.035652 -0.003941  ...  0.031274  0.004798  0.001098  0.004616
# 3  0.066173  0.028177 -0.003515  ... -0.034547  0.012274  0.003193  0.035114
# 4 -0.014199  0.007112 -0.015143  ... -0.006871 -0.014853 -0.000548 -0.039419
#
#        2140      2141      2142      2143      2144      2145
# 0 -0.027109  0.020328 -0.022529  0.004607 -0.027233 -0.021164
# 1 -0.021818  0.003850  0.021547 -0.036095  0.017528  0.013040
# 2  0.003254 -0.036777 -0.011043  0.015351 -0.015193  0.005781
# 3  0.005367 -0.012382  0.012039 -0.038595 -0.008438  0.017386
# 4 -0.002646 -0.009260  0.031820 -0.010483 -0.000283 -0.051815
#
# [5 rows x 2147 columns]
# [8, 134, 1303, 1053]
# factor loadings:  [[-0.02925509 -0.02938129 -0.02913318 -0.02877193]
#  [ 0.00431942  0.00648089  0.01580946  0.00366076]
#  [-0.00394131  0.01712013 -0.00175783  0.00990306]
#  [-0.0035146   0.00670633 -0.00164824 -0.0004129 ]
#  [-0.01514321 -0.00378162 -0.00850384 -0.01945049]]
#
#
# normalized var's in all pc's:  [0.69527492 0.06633969 0.08390617 0.01232904 0.14215018]
# where is pf variance behind market:  [-0.20774203  0.12091951 -0.00462696  0.03644661 -0.10585804]
# eigen pf to invest in:  1
# eigen pf diversity weight:  0.12091950898651371

# %%
mkt_vars = [0.48753289, 0.1872592,  0.07927921, 0.04877565, 0.03629214]
print(mkt_vars)
print(norm_vcs)
print(mkt_vars-norm_vcs)

#===================#
missing_var = mkt_vars-norm_vcs
print(np.argmax(missing_var))
# Out:
# [0.48753289, 0.1872592, 0.07927921, 0.04877565, 0.03629214]
# [0.69527492 0.06633969 0.08390617 0.01232904 0.14215018]
# [-0.20774203  0.12091951 -0.00462696  0.03644661 -0.10585804]
# 1

# %%
pcs.iloc[:, 1:].head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.030085 -0.029522 -0.007507  0.027393 -0.028865 -0.027047  0.000217
# 1  0.010617  0.000309 -0.045032 -0.011908  0.011115  0.011630  0.030397
# 2 -0.001024 -0.003677  0.017107 -0.004644 -0.006589 -0.024006  0.012653
# 3  0.001450 -0.011142 -0.014567 -0.008891 -0.006681  0.008691  0.066173
# 4  0.005724  0.011646 -0.003187  0.005127  0.004913  0.003913 -0.014199
#
#           7         8         9  ...      2136      2137      2138      2139  \
# 0 -0.014549 -0.029255 -0.002692  ... -0.009541  0.028054 -0.028925  0.007041
# 1  0.030052  0.004319 -0.043061  ... -0.032078 -0.006984  0.014673 -0.030121
# 2 -0.035652 -0.003941  0.025153  ...  0.031274  0.004798  0.001098  0.004616
# 3  0.028177 -0.003515  0.004922  ... -0.034547  0.012274  0.003193  0.035114
# 4  0.007112 -0.015143  0.020147  ... -0.006871 -0.014853 -0.000548 -0.039419
#
#        2140      2141      2142      2143      2144      2145
# 0 -0.027109  0.020328 -0.022529  0.004607 -0.027233 -0.021164
# 1 -0.021818  0.003850  0.021547 -0.036095  0.017528  0.013040
# 2  0.003254 -0.036777 -0.011043  0.015351 -0.015193  0.005781
# 3  0.005367 -0.012382  0.012039 -0.038595 -0.008438  0.017386
# 4 -0.002646 -0.009260  0.031820 -0.010483 -0.000283 -0.051815
#
# [5 rows x 2146 columns]
